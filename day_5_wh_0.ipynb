# %%
import requests
api_key="09e2fe97bad8448bac453734242802"
city="vizag"
url=f"http://api.weatherapi.com/v1/current.json?key=key={api_key}&q={city}"
response=requests.get(url)
data=response.json()
print(data)
# Out:
# {'error': {'code': 2008, 'message': 'API key has been disabled.'}}

# %%
import requests
api_key="f250b92b1c974684b718846ff6ec0b03"

url=f"https://newsapi.org/v2/everything?q=tesla&from=2024-01-28&sortBy=publishedAt&apiKey=f250b92b1c974684b718846ff6ec0b03"

response=requests.get(url)
data=response.json()
print(data)
# Out:
# {'status': 'ok', 'totalResults': 12687, 'articles': [{'source': {'id': None, 'name': "Paul Tan's Automotive News"}, 'author': 'Mick Chan', 'title': 'Apple cancels EV, to work on generative AI projects', 'description': 'The Apple Car project is no more, as the company has decided to pivot towards development of artificial intelligence (AI) projects, Bloomberg has reported. According to Bloomberg sources, Apple made the announcement internally, to the […]\nThe post Apple cance…', 'url': 'https://paultan.org/2024/02/28/apple-cancels-ev-to-work-on-generative-ai-projects/', 'urlToImage': 'https://paultan.org/image/2024/02/apple-titan-render-1200x842.jpg', 'publishedAt': '2024-02-28T04:40:09Z', 'content': 'The Apple Car project is no more, as the company has decided to pivot towards development of artificial intelligence (AI) projects, Bloomberg has reported.\r\nAccording to Bloomberg sources, Apple made… [+2247 chars]'}, {'source': {'id': None, 'name': 'Inside.com.tw'}, 'author': 'Chris',
# ...

# %%
import requests

url = "https://distance-calculator8.p.rapidapi.com/calc"

querystring = {"startLatitude":"-26.311960", "startLongitude":"-48.880964","endLatitude":"-26.313662","endLongitude":"-48.881103"}
headers = {
    "X-RapidAPI-Key": "8266ba0ebbmshedb8ed8b6037119p126fb2jsn2ad1740182cc",

    "X-RapidAPI-Host": "distance-calculator8.p.rapidapi.com"
}
response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'statusCode': 200, 'body': {'distance': {'meters': 189.7602141814502, 'kilometers': 0.1897602141814502, 'miles': 0.1179118235931812}}}

# %%
import requests

url = "https://wordsapiv1.p.rapidapi.com/words/hatchback/typeOf"

audioload={
    "audio_code": "en-us-1",
    "text":" Learning the Data Analysis using python sections",
    "speed": "1.55",
    "pitch": "1.55",
    "output_type":"write_url"
}
headers = {
	"X-RapidAPI-Key": "3b0a1820ddmsh4c89455d33300c9p19d377jsnb3dcd01dfb52",
	"X-RapidAPI-Host": "wordsapiv1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'message': 'You are not subscribed to this API.'}
